# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("bodyfat.csv")

# %%
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
df.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=df , x="Density" , y="BodyFat")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True , cmap="coolwarm")
plt.show()

# %%
df_corr = df["Density"].corr(df["BodyFat"])
df_corr
# Out:
# np.float64(-0.9877824021639865)

# %%
df.drop(["Density"] , axis=1 , inplace=True)

# %%
df.head()
# Out:
#    BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  Knee  \
# 0     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0  37.3
# 1      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7  37.3
# 2     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6  38.9
# 3     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1  37.3
# 4     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2  42.2
#
#    Ankle  Biceps  Forearm  Wrist
# 0   21.9    32.0     27.4   17.1
# 1   23.4    30.5     28.9   18.2
# 2   24.0    28.8     25.2   16.6
# 3   22.8    32.4     29.4   18.2
# 4   24.0    32.2     27.7   17.7

# %%
corelation = df_for_corr.corr(numeric_only=True)

# %%
sns.heatmap(corelation , annot=True , cmap="coolwarm")
plt.show()

# %%
def correlation_for_dropping(df, threshold):
    columns_to_drop = set()
    corr = df.corr()
    for i in range(len(corr.columns)):
        for j in range(i):
            if abs(corr.iloc[i, j]) > threshold:
                columns_to_drop.add(corr.columns[i])
    return columns_to_drop

# %%
correlation_for_dropping(df , 0.85)
# Out:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %%
df["Abdomen"].corr(df["Chest"])
# Out:
# np.float64(0.9158276698546782)

# %%
print(df["Abdomen"].corr(df["BodyFat"]))
print(df["Chest"].corr(df["BodyFat"]))
# Out:
# 0.8134322847810489
# 0.7026203388938642

# %%
df.drop(["Chest",'Hip','Knee','Thigh'], axis=1 , inplace=True)

# %%
df
# Out:
#      BodyFat  Age  Weight  Height  Neck  Abdomen  Ankle  Biceps  Forearm  \
# 0       12.3   23  154.25   67.75  36.2     85.2   21.9    32.0     27.4
# 1        6.1   22  173.25   72.25  38.5     83.0   23.4    30.5     28.9
# 2       25.3   22  154.00   66.25  34.0     87.9   24.0    28.8     25.2
# 3       10.4   26  184.75   72.25  37.4     86.4   22.8    32.4     29.4
# 4       28.7   24  184.25   71.25  34.4    100.0   24.0    32.2     27.7
# ..       ...  ...     ...     ...   ...      ...    ...     ...      ...
# 247     11.0   70  134.25   67.00  34.9     83.6   21.5    25.6     25.7
# 248     33.6   72  201.00   69.75  40.9    105.0   23.2    35.2     28.6
# 249     29.3   72  186.75   66.00  38.9    111.5   21.5    31.3     27.2
# 250     26.0   72  190.75   70.50  38.9    101.3   22.7    30.5     29.4
# 251     31.9   74  207.50   70.00  40.8    108.5   24.6    33.7     30.0
#
#      Wrist
# 0     17.1
# 1     18.2
# 2     16.6
# 3     18.2
# 4     17.7
# ..     ...
# ...

# %%
df["Weight"] = df["Weight"]*0.453592
df["Height"] = df["Height"]*2.54

# %%
df["Weight"] = df["Weight"].round(2)

# %%
df["Height"] = df["Height"].round(0)

# %%
df
# Out:
#      BodyFat  Age  Weight  Height  Neck  Abdomen  Ankle  Biceps  Forearm  \
# 0       12.3   23   69.97   172.0  36.2     85.2   21.9    32.0     27.4
# 1        6.1   22   78.58   184.0  38.5     83.0   23.4    30.5     28.9
# 2       25.3   22   69.85   168.0  34.0     87.9   24.0    28.8     25.2
# 3       10.4   26   83.80   184.0  37.4     86.4   22.8    32.4     29.4
# 4       28.7   24   83.57   181.0  34.4    100.0   24.0    32.2     27.7
# ..       ...  ...     ...     ...   ...      ...    ...     ...      ...
# 247     11.0   70   60.89   170.0  34.9     83.6   21.5    25.6     25.7
# 248     33.6   72   91.17   177.0  40.9    105.0   23.2    35.2     28.6
# 249     29.3   72   84.71   168.0  38.9    111.5   21.5    31.3     27.2
# 250     26.0   72   86.52   179.0  38.9    101.3   22.7    30.5     29.4
# 251     31.9   74   94.12   178.0  40.8    108.5   24.6    33.7     30.0
#
#      Wrist
# 0     17.1
# 1     18.2
# 2     16.6
# 3     18.2
# 4     17.7
# ..     ...
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
from scipy.stats import pearsonr
corr, p_value = pearsonr(df["Abdomen"], df["BodyFat"])
print(f"Korelasyon: {corr}, P-değeri: {p_value}")
# Out:
# Korelasyon: 0.8134322847810491, P-değeri: 9.090066724699334e-61

# %%
target = 'BodyFat'
features = [col for col in df.columns if col != target]

print(f"{'Değişken':<15} | {'Korelasyon (r)':<15} | {'P-değeri':<15} | {'Karar'}")
print("-" * 65)

for col in features:
    corr, p = pearsonr(df[col], df[target])
    
    if p < 0.05:
        decision = "Anlamlı"
    else:
        decision = "Anlamsız"
        
    print(f"{col:<15} | {corr:15.4f} | {p:15.3e} | {decision}")
# Out:
# Değişken        | Korelasyon (r)  | P-değeri        | Karar
# -----------------------------------------------------------------
# Age             |          0.2915 |       2.522e-06 | Anlamlı
# Weight          |          0.6124 |       2.461e-27 | Anlamlı
# Height          |         -0.0896 |       1.560e-01 | Anlamsız
# Neck            |          0.4906 |       1.147e-16 | Anlamlı
# Abdomen         |          0.8134 |       9.090e-61 | Anlamlı
# Ankle           |          0.2660 |       1.882e-05 | Anlamlı
# Biceps          |          0.4933 |       7.388e-17 | Anlamlı
# Forearm         |          0.3614 |       3.437e-09 | Anlamlı
# Wrist           |          0.3466 |       1.600e-08 | Anlamlı

# %%
df.drop(["Height"], axis=1 , inplace=True)

# %%
df
# Out:
#      BodyFat  Age  Weight  Neck  Abdomen  Ankle  Biceps  Forearm  Wrist
# 0       12.3   23   69.97  36.2     85.2   21.9    32.0     27.4   17.1
# 1        6.1   22   78.58  38.5     83.0   23.4    30.5     28.9   18.2
# 2       25.3   22   69.85  34.0     87.9   24.0    28.8     25.2   16.6
# 3       10.4   26   83.80  37.4     86.4   22.8    32.4     29.4   18.2
# 4       28.7   24   83.57  34.4    100.0   24.0    32.2     27.7   17.7
# ..       ...  ...     ...   ...      ...    ...     ...      ...    ...
# 247     11.0   70   60.89  34.9     83.6   21.5    25.6     25.7   18.5
# 248     33.6   72   91.17  40.9    105.0   23.2    35.2     28.6   20.1
# 249     29.3   72   84.71  38.9    111.5   21.5    31.3     27.2   18.0
# 250     26.0   72   86.52  38.9    101.3   22.7    30.5     29.4   19.8
# 251     31.9   74   94.12  40.8    108.5   24.6    33.7     30.0   20.9
#
# [252 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(["BodyFat"], axis=1)
y = df["BodyFat"]

# %%
X_train , X_test , y_train , y_test = train_test_split(X, y, test_size=0.20 , random_state=15)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
print(f" Coefficent: {regression.coef_} ")
print(f" Intercept: {regression.intercept_} ")
# Out:
#  Coefficent: [ 0.07675056 -0.21289385 -0.21589228  0.89635078  0.30344099  0.35861845
#   0.36025805 -1.99061453]
#  Intercept: -34.26682598992677

# %%
y_pred_test = regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

# %%
mse = mean_squared_error(y_pred_test , y_test)
mae = mean_absolute_error(y_pred_test , y_test)
score = r2_score(y_pred_test , y_test)
adj_r2 = 1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print("MSE:" , mse)
print("MAE:" , mae)
print("R2 Score:" , score)
print("Adj.R2 Score:" , adj_r2)
# Out:
# MSE: 23.464965952038995
# MAE: 3.7723372895076865
# R2 Score: 0.6000883463432483
# Adj.R2 Score: 0.5239146980276765

# %%
sns.regplot(data=df , x = y_pred_test , y = y_test)
plt.show()

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(regression, X , y , cv=5, scoring="r2")

# %%
cv_scores.mean()
# Out:
# np.float64(0.6595518319697737)

# %%
print(cv_scores)
print(cv_scores.mean())
# Out:
# [0.77806076 0.71134806 0.35711725 0.74273915 0.70849394]
# 0.6595518319697737

# %%
scaler_all = StandardScaler()
X_all_scaled = scaler_all.fit_transform(X) 

y_pred_cv = cross_val_predict(regression, X_all_scaled, y, cv=5)

errors = abs(y - y_pred_cv)
outliers = errors.sort_values(ascending=False).head(10)

print("Modelin en çok zorlandığı (en çok hata yaptığı) satırlar:")
print(outliers)
# Out:
# Modelin en çok zorlandığı (en çok hata yaptığı) satırlar:
# 38     14.270869
# 223    11.925860
# 230    10.180856
# 224    10.083267
# 80     10.045173
# 203     9.897817
# 220     9.624177
# 206     9.198835
# 127     9.116842
# 170     8.900426
# Name: BodyFat, dtype: float64

# %%
outlier_indices = [38, 223, 230, 224, 80, 203, 220, 206, 127, 170]

outlier_data = X.loc[outlier_indices]
print(outlier_data)
# Out:
#      Age  Weight  Neck  Abdomen  Ankle  Biceps  Forearm  Wrist
# 38    46  164.72  51.2    148.1   29.6    45.0     29.0   21.4
# 223   55   64.52  35.2     82.8   22.5    29.4     26.8   17.0
# 230   57   67.02  35.2     86.4   21.3    31.7     27.3   16.9
# 224   55   81.53  41.1     95.3   21.8    34.1     31.1   19.2
# 80    67   74.28  38.4     95.8   23.7    29.4     27.2   19.0
# 203   44   83.46  37.9     89.1   24.0    32.9     29.2   18.4
# 220   54   69.51  38.5     91.8   23.9    31.4     29.9   18.9
# 206   44   75.30  39.1     93.9   21.4    33.1     29.5   17.3
# 127   43   69.06  37.5     78.0   20.8    33.9     28.2   17.4
# 170   35   69.06  37.0     81.9   22.1    30.4     27.4   17.7

# %%
outlier_indices = [38, 223, 230, 224, 80, 203, 220, 206, 127, 170]

X_cleaned = X.drop(index=outlier_indices)
y_cleaned = y.drop(index=outlier_indices)

# %%
X_train , X_test , y_train , y_test = train_test_split(X_cleaned , y_cleaned , test_size=0.2 , random_state=15)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
regression = LinearRegression()
regression.fit(X_train_scaled , y_train)
regression
# Out:
# LinearRegression()

# %%
y_pred_test = regression.predict(X_test_scaled)

# %%
mse = mean_squared_error(y_pred_test , y_test)
mae = mean_absolute_error(y_pred_test , y_test)
score = r2_score(y_pred_test , y_test)
adjr2 = 1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

# %%
print("MSE :" , mse)
print("MAE :", mae)
print("Score :", score)
print("adjr2 :" , adjr2)
# Out:
# MSE : 16.58674423759991
# MAE : 3.277191986994567
# Score : 0.7109301891554445
# adjr2 : 0.6531162269865334

# %%
# Tahmin etmeden önce şunu bastır, bakalım ölçeklenmiş verin ne hale geliyor:
features = np.array([[22, 75, 85, 38, 23, 33, 29, 18]]) # Senin değerlerin
features_scaled = scaler.transform(features)

print("Ölçeklenmiş Girdiler:", features_scaled) # Eğer buradaki sayılar çok büyükse (örn: 10, 50, 100), scaler'ın kafası karışıyor demektir.

sonuc = regression.predict(features_scaled)
print("Tahmin:", sonuc[0])
# Out:
# Ölçeklenmiş Girdiler: [[-1.81312153 -0.49970641 19.92098338 -5.24968075 -0.05502129  0.24554478
#    0.17173335 -0.27949017]]
# Tahmin: -53.629702088001146
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Veri setinden 0. indeksteki kişiyi alalım
kisi = X_cleaned.iloc[0]

# Tahmin fonksiyonunu senin sütun sırasına göre ayarladım
features = np.array([[kisi['Age'], kisi['Weight'], kisi['Neck'], kisi['Abdomen'], 
                      kisi['Ankle'], kisi['Biceps'], kisi['Forearm'], kisi['Wrist']]])

# Ölçekle ve Tahmin Et
features_scaled = scaler.transform(features)
tahmin = regression.predict(features_scaled)

print(f"Modelin Tahmini: %{tahmin[0]:.2f}")
print(f"Gerçek Değer:    %{y_cleaned.iloc[0]:.2f}")
# Out:
# Modelin Tahmini: %15.29
# Gerçek Değer:    %12.30
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import joblib
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# 1. Modeli ve Scaler'ı tekrar eğit
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_cleaned) # Burası X_cleaned'in hazır olmasını bekliyor

regression = LinearRegression()
regression.fit(X_scaled, y_cleaned)        # Burası da y_cleaned'in hazır olmasını bekliyor

# 2. Masaüstüne (veya bulunduğun klasöre) kaydet
joblib.dump(regression, 'vucut_yagi_modeli.pkl')
joblib.dump(scaler, 'scaler.pkl')

print("Dosyalar Masaüstüne başarıyla kaydedildi!")
# Out:
# Dosyalar Masaüstüne başarıyla kaydedildi!

# %%
import os
print(os.path.abspath("scaler.pkl"))
# Out:
# C:\Windows\System32\scaler.pkl

# %%
residuals = y_cleaned - y_pred

plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, bins=30, color='purple')
plt.xlabel("Hata Miktarı (Gerçek - Tahmin)")
plt.ylabel("Frekans")
plt.title("Hata Dağılımı (Model ne kadar yanılıyor?)")
plt.show()
